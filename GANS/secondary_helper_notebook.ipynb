# %%
import os
try:
    
    from google.colab import drive
    drive.mount('/content/gdrive')

    DRIVE_PATH = '/content/gdrive/My\ Drive/NN_DL/GANS' # Sim's path
    # DRIVE_PATH = '/content/gdrive/My\ Drive/UCLA/NN_DL/GANS' # Ran's paths
    DRIVE_PYTHON_PATH = DRIVE_PATH.replace('\\', '')
    if not os.path.exists(DRIVE_PYTHON_PATH):
      # %mkdir $DRIVE_PATH

    ## the space in `My Drive` causes some issues,
    ## make a symlink to avoid this
    SYM_PATH = '/content/GANS'
    if not os.path.exists(SYM_PATH):
      # !ln -s $DRIVE_PATH $SYM_PATH
    
    running_in_colab = True
    
    # We already mounted in our google drive.
    # Enter the foler where you put files in:
    # %cd '/content/GANS'

    # Current working directory:
    # !pwd

    # What files are there:
    # !ls
   
    
except ModuleNotFoundError:
    running_in_colab = False
    print(
        "I guess you are running locally. If you get this message in Colab, check the files."
    )
# Out:
# Mounted at /content/gdrive
# /content/gdrive/.shortcut-targets-by-id/1Fl8lRtFtcplDqGhTruxlsGlVDZByXON0/NN_DL/GANS
# /content/gdrive/.shortcut-targets-by-id/1Fl8lRtFtcplDqGhTruxlsGlVDZByXON0/NN_DL/GANS
# DCGAN-CIFAR10-pytorch  models					  results
# logs		       Performance-comparison-of-GAN-on-cifar-10

# %%
# !ls
# Out:
# amp_1_output.txt  D_flood_2.txt       GD_flood.txt  test_gan_cifar.py
# amp_output.txt	  D_flood.txt	      G_flood.txt   test_image_DCGAN.png
# amp.py		  gan_cifar.py	      no_flood.txt  weights
# cifar10.test.npz  gan_flooding_D.py   output
# data		  gan_flooding_GD.py  __pycache__
# D_flood_1.txt	  gan_flooding_G.py   README.md

# %%
# %cd DCGAN-CIFAR10-pytorch
# Out:
# /content/gdrive/.shortcut-targets-by-id/1Fl8lRtFtcplDqGhTruxlsGlVDZByXON0/NN_DL/GANS/DCGAN-CIFAR10-pytorch

# %%
# !ls
# Out:
# 'amp_1_output (1).txt'	 D_flood.txt		 G_flood.txt
# 'amp_1_output (2).txt'	'gan_cifar_amp (1).py'	 no_flood.txt
# 'amp_1_output (3).txt'	'gan_cifar_amp (2).py'	 output
#  amp_1_output.txt	'gan_cifar_amp (3).py'	 __pycache__
#  amp_output.txt		 gan_cifar_amp.py	 README.md
#  amp.py			 gan_cifar.py		 test_gan_cifar.py
#  cifar10.test.npz	 gan_flooding_D.py	 test_image_DCGAN.png
#  data			 gan_flooding_GD.py	 weights
#  D_flood_1.txt		 gan_flooding_G.py
#  D_flood_2.txt		 GD_flood.txt

# %%
# !git clone https://github.com/hiyouga/AMP-Regularizer.git
# Out:
# Cloning into 'AMP-Regularizer'...
# remote: Enumerating objects: 90, done.
# remote: Counting objects: 100% (90/90), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 90 (delta 45), reused 71 (delta 26), pack-reused 0
# Unpacking objects: 100% (90/90), 82.50 KiB | 89.00 KiB/s, done.

# %%
# !python gan_cifar_amp.py > amp_1_output.txt

# %%
# !readlink -f gan_cifar_amp
# Out:
# /content/gdrive/.shortcut-targets-by-id/1Fl8lRtFtcplDqGhTruxlsGlVDZByXON0/NN_DL/GANS/DCGAN-CIFAR10-pytorch/gan_cifar_amp

# %%
# !python gan_cifar_amp.py
# Out:
# python3: can't open file '/content/gan_cifar_amp.py': [Errno 2] No such file or directory

# %%
# !ls
# Out:
# amp_output.txt	  D_flood_2.txt       gan_flooding_G.py  __pycache__
# amp.py		  D_flood.txt	      GD_flood.txt	 README.md
# cifar10.test.npz  gan_cifar.py	      G_flood.txt	 test_gan_cifar.py
# data		  gan_flooding_D.py   no_flood.txt	 test_image_DCGAN.png
# D_flood_1.txt	  gan_flooding_GD.py  output		 weights
